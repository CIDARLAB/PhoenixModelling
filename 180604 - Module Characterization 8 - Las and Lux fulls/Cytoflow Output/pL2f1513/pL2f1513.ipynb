# %%
from cytoflow import *
# %matplotlib inline

# %%
op_0 = ImportOp(
    conditions={
        'arabinose_uM': 'float',
        'Plasmid': 'category'
    },
    tubes=[
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B1_B01_013.fcs',
            conditions={
                'arabinose_uM': 2000.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B2_B02_014.fcs',
            conditions={
                'arabinose_uM': 1000.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B3_B03_015.fcs',
            conditions={
                'arabinose_uM': 500.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B4_B04_016.fcs',
            conditions={
                'arabinose_uM': 250.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B5_B05_017.fcs',
            conditions={
                'arabinose_uM': 125.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B6_B06_018.fcs',
            conditions={
                'arabinose_uM': 62.5,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B7_B07_019.fcs',
            conditions={
                'arabinose_uM': 31.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B8_B08_020.fcs',
            conditions={
                'arabinose_uM': 16.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B9_B09_021.fcs',
            conditions={
                'arabinose_uM': 8.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B10_B10_022.fcs',
            conditions={
                'arabinose_uM': 4.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B11_B11_023.fcs',
            conditions={
                'arabinose_uM': 2.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_B12_B12_024.fcs',
            conditions={
                'arabinose_uM': 0.0,
                'Plasmid': 'pL2f1513'
            },
            conditions_list=['Plasmid', 'arabinose_uM'])
    ])

ex_0 = op_0.apply()

# %%
op_1 = PolygonOp(
    name='EcoliMorpho',
    vertices=[(1456.5743813758436, 15853.291094781229), (3322.9527545402211,
                                                         477.10600378125253),
              (28460.376766705936, 865.50714125167667), (12074.338410928423,
                                                         20617.323034611134),
              (1517.2771576438415, 15715.046584282483), (1517.2771576438415,
                                                         15715.046584282483)],
    ychannel='SSC-H',
    xchannel='FSC-H',
    xscale='log',
    yscale='log')

ex_1 = op_1.apply(ex_0)

# %%
op_1.default_view().plot(ex_0)

# %%
# Beads: Spherotech RCP-30-5A Lot AG01, AF02, AD04 and AAE01
op_2 = BeadCalibrationOp(
    beads_file=
    'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/BeadsAK02_001/180604 Module Characterizations 8_Specimen_002_B2_B02_002.fcs',
    beads={
        'MECSB': [216.0, 464.0, 1232.0, 2940.0, 7669.0, 19812.0, 35474.0],
        'MEAPCY7': [2864.0, 7644.0, 19081.0, 37258.0],
        'MEAP': [373.0, 1079.0, 3633.0, 9896.0, 28189.0, 79831.0, 151008.0],
        'MEBFP': [861.0, 1997.0, 5776.0, 15233.0, 45389.0, 152562.0, 396759.0],
        'MEPTR': [233.0, 669.0, 2179.0, 5929.0, 18219.0, 63944.0, 188785.0],
        'MEPCY7': [14916.0, 42336.0, 153840.0, 494263.0],
        'MECY':
        [1614.0, 4035.0, 12025.0, 31896.0, 95682.0, 353225.0, 1077421.0],
        'MEPE': [531.0, 1504.0, 4819.0, 12506.0, 36159.0, 109588.0, 250892.0],
        'MEFL': [792.0, 2079.0, 6588.0, 16471.0, 47497.0, 137049.0, 271647.0]
    },
    units={'FITC-A': 'MEFL'})

op_2.estimate(ex_1)
ex_2 = op_2.apply(ex_1)

# %%
op_2.default_view().plot(ex_1)

# %%
op_3 = AutofluorescenceOp(
    channels=['FITC-A'],
    blank_file=
    'Z:/home/delateur/Experiments/BioCPS/180604 - Module Characterization 8 - Las and Lux fulls/Raw Data/180604 Module Characterizations 8/Plate1/180604 Module Characterizations 8_Specimen_001_A1_A01_001.fcs'
)

op_3.estimate(ex_2, subset='(EcoliMorpho == True)')
ex_3 = op_3.apply(ex_2)

# %%
op_3.default_view().plot(ex_2)

# %%
op_4 = ChannelStatisticOp(
    name='GFP Count',
    by=['arabinose_uM'],
    statistic_name='Count',
    subset='(EcoliMorpho == True)',
    function=len,
    channel='FITC-A')

ex_4 = op_4.apply(ex_3)

# %%
from numpy import mean

op_5 = ChannelStatisticOp(
    name='GFP Mean',
    by=['arabinose_uM'],
    statistic_name='Mean',
    function=mean,
    channel='FITC-A')

ex_5 = op_5.apply(ex_4)

# %%
op_6 = ChannelStatisticOp(
    name='GFP GeoMean',
    by=['arabinose_uM'],
    statistic_name='Geom.Mean',
    function=geom_mean,
    channel='FITC-A')

ex_6 = op_6.apply(ex_5)

# %%
TableView(row_facet='arabinose_uM', statistic=('GFP Mean', 'Mean')).plot(ex_6)

# %%
Stats1DView(
    variable_scale='log',
    variable='arabinose_uM',
    statistic=('GFP GeoMean', 'Geom.Mean'),
    scale='log').plot(ex_6)
