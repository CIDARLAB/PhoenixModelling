# %%
from cytoflow import *
# %matplotlib inline

# %%
op_0 = ImportOp(
    tubes=[
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 2000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A1_A01_001.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 1000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A2_A02_002.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 500.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A3_A03_003.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 250.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A4_A04_004.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 125.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A5_A05_005.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 62.5
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A6_A06_006.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 31.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A7_A07_007.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 16.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A8_A08_008.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 8.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A9_A09_009.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 4.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A10_A10_010.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 2.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A11_A11_011.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1EV',
                'arabinose_uM': 0.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A12_A12_012.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 2000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B1_B01_013.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 1000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B2_B02_014.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 500.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B3_B03_015.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 250.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B4_B04_016.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 125.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B5_B05_017.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 62.5
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B6_B06_018.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 31.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B7_B07_019.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 16.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B8_B08_020.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 8.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B9_B09_021.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 4.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B10_B10_022.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 2.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B11_B11_023.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1510',
                'arabinose_uM': 0.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_B12_B12_024.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 2000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C1_C01_025.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 1000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C2_C02_026.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 500.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C3_C03_027.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 250.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C4_C04_028.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 125.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C5_C05_029.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 62.5
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C6_C06_030.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 31.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C7_C07_031.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 16.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C8_C08_032.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 8.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C9_C09_033.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 4.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C10_C10_034.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 2.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C11_C11_035.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1513',
                'arabinose_uM': 0.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_C12_C12_036.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 2000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D1_D01_037.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 1000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D2_D02_038.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 500.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D3_D03_039.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 250.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D4_D04_040.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 125.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D5_D05_041.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 62.5
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D6_D06_042.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 31.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D7_D07_043.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 16.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D8_D08_044.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 8.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D9_D09_045.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 4.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D10_D10_046.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 2.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D11_D11_047.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1542',
                'arabinose_uM': 0.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_D12_D12_048.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 2000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E1_E01_049.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 1000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E2_E02_050.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 500.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E3_E03_051.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 250.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E4_E04_052.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 125.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E5_E05_053.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 62.5
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E6_E06_054.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 31.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E7_E07_055.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 16.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E8_E08_056.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 8.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E9_E09_057.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 4.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E10_E10_058.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 2.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E11_E11_059.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1532',
                'arabinose_uM': 0.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_E12_E12_060.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 2000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F1_F01_061.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 1000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F2_F02_062.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 500.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F3_F03_063.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 250.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F4_F04_064.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 125.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F5_F05_065.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 62.5
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F6_F06_066.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 31.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F7_F07_067.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 16.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F8_F08_068.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 8.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F9_F09_069.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 4.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F10_F10_070.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 2.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F11_F11_071.fcs'
        ),
        Tube(
            conditions={
                'Plasmid': 'pL2f1537',
                'arabinose_uM': 0.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_F12_F12_072.fcs'
        )
    ],
    conditions={
        'Plasmid': 'category',
        'arabinose_uM': 'float'
    })

ex_0 = op_0.apply()

# %%
op_1 = PolygonOp(
    xscale='log',
    name='EcoliMorpho',
    yscale='log',
    xchannel='FSC-H',
    ychannel='SSC-H',
    vertices=[(1473.533158865685, 20729.01785506553), (2962.775951914728,
                                                       5417.8402971193445),
              (3869.7359370887293,
               1672.7908080211969), (3183.64675367205,
                                     702.0474547122875), (9653.802671744324,
                                                          481.4889750955223),
              (24331.919460659217,
               604.8061357359077), (30816.001852837093,
                                    2662.625921184136), (25093.36875197755,
                                                         12355.410044575201),
              (6206.991822800853,
               26038.05660147385), (1458.475194342963,
                                    20911.614570211175), (1458.475194342963,
                                                          20911.614570211175)])

ex_1 = op_1.apply(ex_0)

# %%
op_1.default_view(huefacet='arabinose_uM').plot(ex_0)

# %%
# Beads: Spherotech RCP-30-5A Lot AG01, AF02, AD04 and AAE01
op_2 = BeadCalibrationOp(
    units={'FITC-A': 'MEFL'},
    beads_file=
    'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/BeadsAK02/180602 Module Characterizations 7_Specimen_001_G1_G01_001.fcs',
    beads={
        'MEAPCY7': [2864.0, 7644.0, 19081.0, 37258.0],
        'MECY':
        [1614.0, 4035.0, 12025.0, 31896.0, 95682.0, 353225.0, 1077421.0],
        'MEPE': [531.0, 1504.0, 4819.0, 12506.0, 36159.0, 109588.0, 250892.0],
        'MECSB': [216.0, 464.0, 1232.0, 2940.0, 7669.0, 19812.0, 35474.0],
        'MEPTR': [233.0, 669.0, 2179.0, 5929.0, 18219.0, 63944.0, 188785.0],
        'MEFL': [792.0, 2079.0, 6588.0, 16471.0, 47497.0, 137049.0, 271647.0],
        'MEPCY7': [14916.0, 42336.0, 153840.0, 494263.0],
        'MEBFP': [861.0, 1997.0, 5776.0, 15233.0, 45389.0, 152562.0, 396759.0],
        'MEAP': [373.0, 1079.0, 3633.0, 9896.0, 28189.0, 79831.0, 151008.0]
    })

op_2.estimate(ex_1)
ex_2 = op_2.apply(ex_1)

# %%
op_2.default_view().plot(ex_1)

# %%
op_3 = AutofluorescenceOp(
    channels=['FITC-A'],
    blank_file=
    'Z:/home/delateur/Experiments/BioCPS/180602 - Module Characterization 7 - Ara inductions/180602 Module Characterizations 7/Plate1A/180602 Module Characterizations 7_Specimen_001_A12_A12_012.fcs'
)

op_3.estimate(ex_2, subset='(EcoliMorpho == True)')
ex_3 = op_3.apply(ex_2)

# %%
op_3.default_view().plot(ex_2)

# %%
op_4 = ChannelStatisticOp(
    statistic_name='Count',
    by=['Plasmid', 'arabinose_uM'],
    name='GFP Count',
    function=len,
    subset='(EcoliMorpho == True)',
    channel='FSC-H')

ex_4 = op_4.apply(ex_3)

# %%
from numpy import mean

op_5 = ChannelStatisticOp(
    statistic_name='Mean',
    by=['arabinose_uM', 'Plasmid'],
    name='GFP Mean',
    function=mean,
    subset='(EcoliMorpho == True)',
    channel='FITC-A')

ex_5 = op_5.apply(ex_4)

# %%
op_6 = ChannelStatisticOp(
    statistic_name='Geom.Mean',
    by=['arabinose_uM', 'Plasmid'],
    name='GFP GeoMean',
    function=geom_mean,
    subset='(EcoliMorpho == True)',
    channel='FITC-A')

ex_6 = op_6.apply(ex_5)

# %%
TableView(
    row_facet='arabinose_uM',
    statistic=('GFP Mean', 'Mean'),
    column_facet='Plasmid').plot(ex_6)

# %%
Stats1DView(
    huefacet='Plasmid',
    scale='log',
    variable='arabinose_uM',
    variable_scale='log',
    statistic=('GFP GeoMean', 'Geom.Mean')).plot(ex_6)
