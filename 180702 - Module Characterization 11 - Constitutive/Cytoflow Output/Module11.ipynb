# %%
from cytoflow import *
# %matplotlib inline

# %%
op_0 = ImportOp(
    conditions={
        'plasmid': 'category',
        'replicate': 'category'
    },
    tubes=[
        Tube(
            conditions={
                'plasmid': 'pL2f1583',
                'replicate': '1'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_A2_A02_004.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1584',
                'replicate': '1'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_A3_A03_005.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1585',
                'replicate': '1'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_A4_A04_006.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1586',
                'replicate': '1'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_A5_A05_007.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1587',
                'replicate': '1'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_A6_A06_008.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1588',
                'replicate': '1'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_A7_A07_009.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1589',
                'replicate': '1'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_A8_A08_010.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1590',
                'replicate': '1'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_A9_A09_011.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1583',
                'replicate': '2'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_B2_B02_016.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1584',
                'replicate': '2'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_B3_B03_017.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1586',
                'replicate': '2'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_B5_B05_019.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1585',
                'replicate': '2'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_B4_B04_018.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1587',
                'replicate': '2'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_B6_B06_020.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1588',
                'replicate': '2'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_B7_B07_021.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1589',
                'replicate': '2'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_B8_B08_022.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1590',
                'replicate': '2'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_B9_B09_023.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1583',
                'replicate': '3'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_C2_C02_028.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1584',
                'replicate': '3'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_C3_C03_029.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1585',
                'replicate': '3'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_C4_C04_030.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1586',
                'replicate': '3'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_C5_C05_031.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1587',
                'replicate': '3'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_C6_C06_032.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1588',
                'replicate': '3'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_C7_C07_033.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1589',
                'replicate': '3'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_C8_C08_034.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1590',
                'replicate': '3'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_C9_C09_035.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1583',
                'replicate': '4'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_D2_D02_040.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1584',
                'replicate': '4'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_D3_D03_041.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1585',
                'replicate': '4'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_D4_D04_042.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1586',
                'replicate': '4'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_D5_D05_043.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1587',
                'replicate': '4'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_D6_D06_044.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1588',
                'replicate': '4'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_D7_D07_045.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1589',
                'replicate': '4'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_D8_D08_046.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1590',
                'replicate': '4'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_D9_D09_047.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1583',
                'replicate': '5'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_E2_E02_052.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1585',
                'replicate': '5'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_E4_E04_054.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1584',
                'replicate': '5'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_E3_E03_053.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1590',
                'replicate': '5'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_E9_E09_059.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1589',
                'replicate': '5'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_E8_E08_058.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1588',
                'replicate': '5'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_E7_E07_057.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1586',
                'replicate': '5'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_E5_E05_055.fcs',
            conditions_list=['plasmid', 'replicate']),
        Tube(
            conditions={
                'plasmid': 'pL2f1587',
                'replicate': '5'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_E6_E06_056.fcs',
            conditions_list=['plasmid', 'replicate'])
    ])

ex_0 = op_0.apply()

# %%
op_1 = PolygonOp(
    xscale='log',
    name='EcoliMorpho',
    yscale='log',
    xchannel='FSC-H',
    ychannel='SSC-H',
    vertices=[(868.03759519838218, 2183.9988933271352), (2051.8446740411391,
                                                         881.87365610421853),
              (11373.576665003628, 2733.8595324642961), (3640.9533296182562,
                                                         8116.9234481993699),
              (881.97680486111278, 2146.5973285577379), (881.97680486111278,
                                                         2146.5973285577379)])

ex_1 = op_1.apply(ex_0)

# %%
op_1.default_view().plot(ex_0)

# %%
# Beads: Spherotech RCP-30-5A Lot AG01, AF02, AD04 and AAE01
op_2 = BeadCalibrationOp(
    beads={
        'MECSB': [216.0, 464.0, 1232.0, 2940.0, 7669.0, 19812.0, 35474.0],
        'MEAP': [373.0, 1079.0, 3633.0, 9896.0, 28189.0, 79831.0, 151008.0],
        'MEBFP': [861.0, 1997.0, 5776.0, 15233.0, 45389.0, 152562.0, 396759.0],
        'MEPTR': [233.0, 669.0, 2179.0, 5929.0, 18219.0, 63944.0, 188785.0],
        'MEPCY7': [14916.0, 42336.0, 153840.0, 494263.0],
        'MECY':
        [1614.0, 4035.0, 12025.0, 31896.0, 95682.0, 353225.0, 1077421.0],
        'MEAPCY7': [2864.0, 7644.0, 19081.0, 37258.0],
        'MEFL': [792.0, 2079.0, 6588.0, 16471.0, 47497.0, 137049.0, 271647.0],
        'MEPE': [531.0, 1504.0, 4819.0, 12506.0, 36159.0, 109588.0, 250892.0]
    },
    units={'FITC-A': 'MEFL'},
    beads_file=
    'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/BeadsAK02/180703 Module Characterizations 11_Specimen_001_B1_B01_001.fcs'
)

op_2.estimate(ex_1)
ex_2 = op_2.apply(ex_1)

# %%
op_2.default_view().plot(ex_1)

# %%
op_3 = AutofluorescenceOp(
    channels=['FITC-A'],
    blank_file=
    'Z:/home/delateur/Experiments/BioCPS/180702 - Module Characterization 11 - Constitutive/Raw Data/180703 Module Characterizations 11/Plate1/180703 Module Characterizations 11_Specimen_001_E1_E01_051.fcs'
)

op_3.estimate(ex_2, subset='(EcoliMorpho == True)')
ex_3 = op_3.apply(ex_2)

# %%
op_3.default_view().plot(ex_2)

# %%
op_4 = ChannelStatisticOp(
    name='GFP_Count',
    channel='FITC-A',
    function=len,
    statistic_name='Count',
    by=['plasmid', 'replicate'],
    subset='(EcoliMorpho == True)')

ex_4 = op_4.apply(ex_3)

# %%
from numpy import mean

op_5 = ChannelStatisticOp(
    name='GFP_Mean',
    channel='FITC-A',
    function=mean,
    statistic_name='Mean',
    by=['replicate', 'plasmid'],
    subset='(EcoliMorpho == True)')

ex_5 = op_5.apply(ex_4)

# %%
op_6 = ChannelStatisticOp(
    name='GFP_GeoMean',
    channel='FITC-A',
    function=geom_mean,
    statistic_name='Geom.Mean',
    by=['replicate', 'plasmid'],
    subset='(EcoliMorpho == True)')

ex_6 = op_6.apply(ex_5)

# %%
BarChartView(
    huefacet='replicate',
    statistic=('GFP_GeoMean', 'Geom.Mean'),
    scale='log',
    variable='plasmid').plot(
        ex_6, title='`')

# %%
TableView(
    column_facet='replicate',
    row_facet='plasmid',
    statistic=('GFP_GeoMean', 'Geom.Mean')).plot(ex_6)
