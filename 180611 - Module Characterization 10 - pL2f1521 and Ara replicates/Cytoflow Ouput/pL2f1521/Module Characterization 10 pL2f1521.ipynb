# %%
from cytoflow import *
# %matplotlib inline

# %%
op_0 = ImportOp(
    tubes=[
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'plasmid': 'pL2f1521',
                'arabinose_uM': 2000.0
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A1_A01_001.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 1000.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A2_A02_002.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 500.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A3_A03_003.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 250.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A4_A04_004.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 125.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A5_A05_005.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 63.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A6_A06_006.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 31.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A7_A07_007.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 16.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A8_A08_008.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 8.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A9_A09_009.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 4.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A10_A10_010.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 2.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A11_A11_011.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.0,
                'arabinose_uM': 0.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_A12_A12_012.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 2000.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B1_B01_013.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 1000.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B2_B02_014.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 500.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B3_B03_015.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 250.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B4_B04_016.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 125.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B5_B05_017.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 63.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B6_B06_018.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 31.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B7_B07_019.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 16.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B8_B08_020.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 8.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B9_B09_021.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 4.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B10_B10_022.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 2.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B11_B11_023.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 0.1,
                'arabinose_uM': 0.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_B12_B12_024.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 2000.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C1_C01_025.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 1000.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C2_C02_026.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 500.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C3_C03_027.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 250.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C4_C04_028.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 125.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C5_C05_029.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 63.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C6_C06_030.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 31.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C7_C07_031.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 16.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C8_C08_032.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 8.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C9_C09_033.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 4.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C10_C10_034.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 2.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C11_C11_035.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 1.0,
                'arabinose_uM': 0.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_C12_C12_036.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 2000.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D1_D01_037.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 1000.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D2_D02_038.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 500.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D3_D03_039.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 250.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D4_D04_040.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 125.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D5_D05_041.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 63.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D6_D06_042.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 31.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D7_D07_043.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 16.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D8_D08_044.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 8.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D9_D09_045.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 4.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D10_D10_046.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 2.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D11_D11_047.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 10.0,
                'arabinose_uM': 0.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_D12_D12_048.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 100.0,
                'arabinose_uM': 2000.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_E1_E01_049.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM': 100.0,
                'arabinose_uM': 1000.0,
                'plasmid': 'pL2f1521'
            },
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_E2_E02_050.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM']),
        Tube(
            conditions={
                'rhlAHL_nM':
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate3/180620 Module Characterizations 10_Specimen_001_H12_H12_096.fcs',
            conditions_list=['plasmid', 'rhlAHL_nM', 'arabinose_uM'])
    ],
    conditions={
        'rhlAHL_nM': 'float',
        'plasmid': 'category',
        'arabinose_uM': 'float'
    })

ex_0 = op_0.apply()

# %%
op_1 = PolygonOp(
    xchannel='FSC-H',
    vertices=[(1864.2750197928278, 16599.067151545001), (5322.5134319520457,
                                                         574.53816090044415),
              (16078.895955957993,
               983.42231695892883), (19993.197204395696,
                                     9697.5605998068077), (6154.6134642657271,
                                                           25828.038581044162),
              (1733.676139573615, 15486.911621173702), (1733.676139573615,
                                                        15486.911621173702)],
    name='EcoliMorpho',
    xscale='log',
    ychannel='SSC-H',
    yscale='log')

ex_1 = op_1.apply(ex_0)

# %%
op_1.default_view().plot(ex_0)

# %%
# Beads: Spherotech RCP-30-5A Lot AG01, AF02, AD04 and AAE01
op_2 = BeadCalibrationOp(
    beads={
        'MEAP': [373.0, 1079.0, 3633.0, 9896.0, 28189.0, 79831.0, 151008.0],
        'MEFL': [792.0, 2079.0, 6588.0, 16471.0, 47497.0, 137049.0, 271647.0],
        'MEPCY7': [14916.0, 42336.0, 153840.0, 494263.0],
        'MEAPCY7': [2864.0, 7644.0, 19081.0, 37258.0],
        'MEBFP': [861.0, 1997.0, 5776.0, 15233.0, 45389.0, 152562.0, 396759.0],
        'MEPE': [531.0, 1504.0, 4819.0, 12506.0, 36159.0, 109588.0, 250892.0],
        'MEPTR': [233.0, 669.0, 2179.0, 5929.0, 18219.0, 63944.0, 188785.0],
        'MECSB': [216.0, 464.0, 1232.0, 2940.0, 7669.0, 19812.0, 35474.0],
        'MECY':
        [1614.0, 4035.0, 12025.0, 31896.0, 95682.0, 353225.0, 1077421.0]
    },
    beads_file=
    'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/BeadsAK02/180604 Module Characterizations 8_001_Specimen_001_B1_B01_001.fcs',
    units={'FITC-A': 'MEFL'})

op_2.estimate(ex_1)
ex_2 = op_2.apply(ex_1)

# %%
op_2.default_view().plot(ex_1)

# %%
op_3 = AutofluorescenceOp(
    channels=['FITC-A'],
    blank_file=
    'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_A1_A01_001.fcs'
)

op_3.estimate(ex_2, subset='(EcoliMorpho == True)')
ex_3 = op_3.apply(ex_2)

# %%
op_3.default_view().plot(ex_2)

# %%
op_4 = ChannelStatisticOp(
    by=['rhlAHL_nM', 'arabinose_uM'],
    function=len,
    subset='(EcoliMorpho == True)',
    name='GFP_Count',
    channel='FITC-A',
    statistic_name='Count')

ex_4 = op_4.apply(ex_3)

# %%
from numpy import mean

op_5 = ChannelStatisticOp(
    by=['rhlAHL_nM', 'arabinose_uM'],
    function=mean,
    subset='(EcoliMorpho == True)',
    name='GFP_Mean',
    channel='FITC-A',
    statistic_name='Mean')

ex_5 = op_5.apply(ex_4)

# %%
op_6 = ChannelStatisticOp(
    by=['rhlAHL_nM', 'arabinose_uM'],
    function=geom_mean,
    subset='(EcoliMorpho == True)',
    name='GFP_GeoMean',
    channel='FITC-A',
    statistic_name='Geom.Mean')

ex_6 = op_6.apply(ex_5)

# %%
Stats1DView(
    statistic=('GFP_GeoMean', 'Geom.Mean'),
    huefacet='arabinose_uM',
    scale='log',
    variable='rhlAHL_nM',
    huescale='log',
    variable_scale='log').plot(ex_6)

# %%
TableView(
    statistic=('GFP_GeoMean', 'Geom.Mean'),
    row_facet='arabinose_uM',
    column_facet='rhlAHL_nM').plot(ex_6)
