# %%
from cytoflow import *
# %matplotlib inline

# %%
op_0 = ImportOp(
    tubes=[
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D1_D01_037.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 2000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D2_D02_038.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 1000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D3_D03_039.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 500.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D4_D04_040.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 250.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D5_D05_041.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 125.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D6_D06_042.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 63.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D7_D07_043.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 31.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D8_D08_044.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 16.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D9_D09_045.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 8.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D10_D10_046.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 4.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D11_D11_047.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 2.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_D12_D12_048.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 0.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E1_E01_049.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 2000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E2_E02_050.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 1000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E3_E03_051.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 500.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E4_E04_052.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 250.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E5_E05_053.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 125.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E6_E06_054.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 63.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E7_E07_055.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 31.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E8_E08_056.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 16.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E9_E09_057.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 8.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E10_E10_058.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 4.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E11_E11_059.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 2.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_E12_E12_060.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 0.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F1_F01_061.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 2000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F2_F02_062.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 1000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F3_F03_063.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 500.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F4_F04_064.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 250.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F5_F05_065.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 125.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F6_F06_066.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 63.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F7_F07_067.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 31.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F8_F08_068.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 16.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F9_F09_069.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 8.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F10_F10_070.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 4.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F11_F11_071.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 2.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate2/180620 Module Characterizations 10_Specimen_001_F12_F12_072.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 0.0
            },
            conditions_list=['arabinose_uM', 'replicate'])
    ],
    conditions={
        'replicate': 'category',
        'arabinose_uM': 'float'
    })

ex_0 = op_0.apply()

# %%
op_1 = PolygonOp(
    xchannel='FSC-H',
    yscale='log',
    xscale='log',
    ychannel='SSC-H',
    vertices=[(1690.5494431703842, 10369.191764802923), (2589.2200169371949,
                                                         655.56231330130549),
              (11975.82453286417, 796.5540329666477), (10722.742708369011,
                                                       11002.544059419195),
              (1677.2559396637712, 10369.191764802923), (1677.2559396637712,
                                                         10369.191764802923)],
    name='EcoliMorpho')

ex_1 = op_1.apply(ex_0)

# %%
op_1.default_view().plot(ex_0)

# %%
# Beads: Spherotech RCP-30-5A Lot AG01, AF02, AD04 and AAE01
op_2 = BeadCalibrationOp(
    units={'FITC-A': 'MEFL'},
    beads_file=
    'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/BeadsAK02/180604 Module Characterizations 8_001_Specimen_001_B1_B01_001.fcs',
    beads={
        'MECY':
        [1614.0, 4035.0, 12025.0, 31896.0, 95682.0, 353225.0, 1077421.0],
        'MECSB': [216.0, 464.0, 1232.0, 2940.0, 7669.0, 19812.0, 35474.0],
        'MEAPCY7': [2864.0, 7644.0, 19081.0, 37258.0],
        'MEFL': [792.0, 2079.0, 6588.0, 16471.0, 47497.0, 137049.0, 271647.0],
        'MEBFP': [861.0, 1997.0, 5776.0, 15233.0, 45389.0, 152562.0, 396759.0],
        'MEAP': [373.0, 1079.0, 3633.0, 9896.0, 28189.0, 79831.0, 151008.0],
        'MEPTR': [233.0, 669.0, 2179.0, 5929.0, 18219.0, 63944.0, 188785.0],
        'MEPE': [531.0, 1504.0, 4819.0, 12506.0, 36159.0, 109588.0, 250892.0],
        'MEPCY7': [14916.0, 42336.0, 153840.0, 494263.0]
    })

op_2.estimate(ex_1)
ex_2 = op_2.apply(ex_1)

# %%
op_2.default_view().plot(ex_1)

# %%
op_3 = AutofluorescenceOp(
    channels=['FITC-A'],
    blank_file=
    'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_A1_A01_001.fcs'
)

op_3.estimate(ex_2)
ex_3 = op_3.apply(ex_2)

# %%
op_3.default_view().plot(ex_2)

# %%
op_4 = ChannelStatisticOp(
    by=['replicate', 'arabinose_uM'],
    channel='FITC-A',
    name='GFP_Count',
    function=len,
    statistic_name='Count',
    subset='(EcoliMorpho == True)')

ex_4 = op_4.apply(ex_3)

# %%
from numpy import mean

op_5 = ChannelStatisticOp(
    by=['arabinose_uM', 'replicate'],
    channel='FITC-A',
    name='GFP_Mean',
    function=mean,
    statistic_name='Mean',
    subset='(EcoliMorpho == True)')

ex_5 = op_5.apply(ex_4)

# %%
op_6 = ChannelStatisticOp(
    by=['arabinose_uM', 'replicate'],
    channel='FITC-A',
    name='GFP_GeoMean',
    function=geom_mean,
    statistic_name='Geom.Mean',
    subset='(EcoliMorpho == True)')

ex_6 = op_6.apply(ex_5)

# %%
Stats1DView(
    scale='log',
    statistic=('GFP_GeoMean', 'Geom.Mean'),
    huefacet='replicate',
    variable_scale='log',
    variable='arabinose_uM').plot(ex_6)

# %%
TableView(
    row_facet='arabinose_uM',
    column_facet='replicate',
    statistic=('GFP_GeoMean', 'Geom.Mean')).plot(ex_6)
