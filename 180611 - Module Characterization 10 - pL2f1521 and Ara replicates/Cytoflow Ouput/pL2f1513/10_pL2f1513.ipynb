# %%
from cytoflow import *
# %matplotlib inline

# %%
op_0 = ImportOp(
    tubes=[
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B1_B01_004.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 2000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B2_B02_005.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 1000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B3_B03_006.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 500.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B4_B04_007.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 250.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B5_B05_008.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 125.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B6_B06_009.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 63.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B7_B07_010.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 31.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B8_B08_011.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 16.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B9_B09_012.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 8.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B10_B10_013.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 4.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B11_B11_014.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 2.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_B12_B12_015.fcs',
            conditions={
                'replicate': '1',
                'arabinose_uM': 0.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C1_C01_016.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 2000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C2_C02_017.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 1000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C3_C03_018.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 500.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C4_C04_019.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 250.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C5_C05_020.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 125.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C6_C06_021.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 63.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C7_C07_022.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 31.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C8_C08_023.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 16.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C9_C09_024.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 8.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C10_C10_025.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 4.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C11_C11_026.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 2.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_C12_C12_027.fcs',
            conditions={
                'replicate': '2',
                'arabinose_uM': 0.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D1_D01_028.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 2000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D2_D02_029.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 1000.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D3_D03_030.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 500.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D4_D04_031.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 250.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D5_D05_032.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 125.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D6_D06_033.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 63.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D7_D07_034.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 31.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D8_D08_035.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 16.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D9_D09_036.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 8.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D10_D10_037.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 4.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D11_D11_038.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 2.0
            },
            conditions_list=['arabinose_uM', 'replicate']),
        Tube(
            file=
            'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_D12_D12_039.fcs',
            conditions={
                'replicate': '3',
                'arabinose_uM': 0.0
            },
            conditions_list=['arabinose_uM', 'replicate'])
    ],
    conditions={
        'replicate': 'category',
        'arabinose_uM': 'float'
    })

ex_0 = op_0.apply()

# %%
op_1 = PolygonOp(
    xchannel='FSC-H',
    yscale='log',
    xscale='log',
    ychannel='SSC-H',
    vertices=[(1690.5494431703842, 10369.191764802923), (2589.2200169371949,
                                                         655.56231330130549),
              (11975.82453286417, 796.5540329666477), (10722.742708369011,
                                                       11002.544059419195),
              (1677.2559396637712, 10369.191764802923), (1677.2559396637712,
                                                         10369.191764802923)],
    name='EcoliMorpho')

ex_1 = op_1.apply(ex_0)

# %%
op_1.default_view().plot(ex_0)

# %%
# Beads: Spherotech RCP-30-5A Lot AG01, AF02, AD04 and AAE01
op_2 = BeadCalibrationOp(
    units={'FITC-A': 'MEFL'},
    beads_file=
    'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/BeadsAK02/180604 Module Characterizations 8_001_Specimen_001_B1_B01_001.fcs',
    beads={
        'MECY':
        [1614.0, 4035.0, 12025.0, 31896.0, 95682.0, 353225.0, 1077421.0],
        'MECSB': [216.0, 464.0, 1232.0, 2940.0, 7669.0, 19812.0, 35474.0],
        'MEAPCY7': [2864.0, 7644.0, 19081.0, 37258.0],
        'MEFL': [792.0, 2079.0, 6588.0, 16471.0, 47497.0, 137049.0, 271647.0],
        'MEBFP': [861.0, 1997.0, 5776.0, 15233.0, 45389.0, 152562.0, 396759.0],
        'MEAP': [373.0, 1079.0, 3633.0, 9896.0, 28189.0, 79831.0, 151008.0],
        'MEPTR': [233.0, 669.0, 2179.0, 5929.0, 18219.0, 63944.0, 188785.0],
        'MEPE': [531.0, 1504.0, 4819.0, 12506.0, 36159.0, 109588.0, 250892.0],
        'MEPCY7': [14916.0, 42336.0, 153840.0, 494263.0]
    })

op_2.estimate(ex_1)
ex_2 = op_2.apply(ex_1)

# %%
op_2.default_view().plot(ex_1)

# %%
op_3 = AutofluorescenceOp(
    channels=['FITC-A'],
    blank_file=
    'Z:/home/delateur/Experiments/BioCPS/180611 - Module Characterization 10 - pL2f1521 and Ara replicates/Raw Data/Plate1/180620 Module Characterizations 10_Specimen_001_A1_A01_001.fcs'
)

op_3.estimate(ex_2, subset='(EcoliMorpho == True)')
ex_3 = op_3.apply(ex_2)

# %%
op_3.default_view().plot(ex_2)

# %%
op_4 = ChannelStatisticOp(
    by=['replicate', 'arabinose_uM'],
    channel='FITC-A',
    name='GFP_Count',
    function=len,
    statistic_name='Count',
    subset='(EcoliMorpho == True)')

ex_4 = op_4.apply(ex_3)

# %%
from numpy import mean

op_5 = ChannelStatisticOp(
    by=['arabinose_uM', 'replicate'],
    channel='FITC-A',
    name='GFP_Mean',
    function=mean,
    statistic_name='Mean',
    subset='(EcoliMorpho == True)')

ex_5 = op_5.apply(ex_4)

# %%
op_6 = ChannelStatisticOp(
    by=['arabinose_uM', 'replicate'],
    channel='FITC-A',
    name='GFP_GeoMean',
    function=geom_mean,
    statistic_name='Geom.Mean',
    subset='(EcoliMorpho == True)')

ex_6 = op_6.apply(ex_5)

# %%
Stats1DView(
    scale='log',
    statistic=('GFP_GeoMean', 'Geom.Mean'),
    huefacet='replicate',
    variable_scale='log',
    variable='arabinose_uM').plot(ex_6)

# %%
TableView(
    row_facet='arabinose_uM',
    column_facet='replicate',
    statistic=('GFP_GeoMean', 'Geom.Mean')).plot(ex_6)
